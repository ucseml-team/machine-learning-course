# %% [markdown]
# Machine Learning
# ================

# %% [markdown]
# Qué es?
# =======

# %% [markdown]
# - Rama de la inteligencia artificial
# - Muy en auge actualmente, muy útil
# - Programas que "aprenden desde los datos"
# - Cercana a la estadística y métodos matemáticos

# %% [markdown]
# # Inteligencia artificial

# %% [markdown]
# ![](files/images/AI_topics.PNG)

# %% [markdown]
# # Qué es visión por computador (o computer vision)?

# %% [markdown]
# - Se ocupa de crear computadoras que tengan la capacidad de "ver"
# - No se trata solo de mirar, sino de obtener información a partir de imágenes

# %% [markdown]
# ![](files/images/CV_example_1.jpg)

# %% [markdown]
# ![](files/images/CV_example_2.jpg)

# %% [markdown]
# ![](files/images/CV_example_3.PNG)

# %% [markdown]
# ![](files/images/CV_example_4.PNG)

# %% [markdown]
# ![](files/images/CV_example_5.PNG)

# %% [markdown]
# # Es un problema simple?

# %% [markdown]
# TODO LO CONTRARIO!

# %% [markdown]
# ![](files/images/CV_intro.png)

# %% [markdown]
# Los mismos objetos pueden ser terriblemente distintos
#
# ![](files/images/CV_intro_1.png)

# %% [markdown]
# ![](files/images/CV_intro_2.PNG)

# %% [markdown]
# Incluso para los mismos objetos pueden existir distintas luces, sobras y particularidades de la imagen
#
# ![](files/images/CV_intro_3.PNG)

# %% [markdown]
# Y los objetos tienen geometría variable !
#
# ![](files/images/CV_intro_4.PNG)

# %% [markdown]
# Y como si todo esto fuese poco, los mismos objetos con la misma geometría y bajo las mismas condiciones, pueden deformarse !
#
# ![](files/images/CV_intro_5.jpg)

# %% [markdown]
# # Parece fácil, no ? Adivinen de qué trata el próximo TP?
#
# <img src="http://www.reactiongifs.com/r/UyHrWY1.gif" alt="">

# %% [markdown]
# # Algunas aplicaciones reales

# %% [markdown]
# ## Reconocimiento óptico de caracteres (OCR)
#
# ![](files/images/CV_intro_6.jpg)

# %% [markdown]
# ![](files/images/CV_intro_7.jpg)

# %% [markdown]
# ## Biometría
#
# ![](files/images/CV_intro_5.PNG)

# %% [markdown]
# ## Reconstrucción 3D
#
# ![](files/images/CV_intro_6.png)

# %% [markdown]
# ## Cine (animación gráfica, realidad aumentada)
#
# ![](files/images/CV_intro_7.png)

# %% [markdown]
# ![](files/images/CV_intro_13.png)

# %% [markdown]
# ## Fotografía
#
# ![](files/images/CV_intro_8.PNG)

# %% [markdown]
# ## Robótica
#
# ![](files/images/CV_intro_9.PNG)

# %% [markdown]
# DARPA Grand Challenge
# ![](files/images/CV_intro_14.jpeg)

# %% [markdown]
# ## Marketing y publicidad
#
# Publicidad sin demoras que no puede saltarse
# ![](files/images/CV_intro_11.PNG)

# %% [markdown]
# ## Análisis de comportamiento
#
# ![](files/images/CV_intro_12.PNG)

# %% [markdown]
# # Sub-campos dentro de visión por computadora
#
# ![](files/images/CV_topics.png)

# %% [markdown]
# ## Recapitulando: machine learning o computer vision?

# %% [markdown]
# ## En nuestro caso, las dos !

# %% [markdown]
# ### En muchos problemas de CV podemos hacer que una máquina aprenda de los datos.
#
# - Reconocimiento de caras
# - Detección de objetos
# - Segmentación de imágenes
# - Reconocimiento de expresiones/emociones
# - Detección de estilos

# %% [markdown]
# ### Tenemos dos formas principales de hacerlo para construir las entradas:
#
# - Obtener conocimiento de la imagen usando técnicas de CV
#
# ![](files/images/CV_approach_1.PNG)
#
# - Obtener una representación digital de la imagen (matriz)
#
# ![](files/images/CV_approach_2.PNG)

# %% [markdown]
# # Conclusión

# %% [markdown]
# - IA ≠ CV ≠ ML
# - CV ataca distintos problemas, y solo algunos de ellos pueden resolverse utilizando ML
# - Por distintos aspectos, hacer que una máquina tenga la capacidad de "ver" no es trivial
# - Si bien en las últimas décadas hubo grandes avances, queda mucho camino por recorrer
